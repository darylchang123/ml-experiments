# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ## Try out 3d plotting in matplotlib

# %%
def f(x, y):
    return -(np.cos(x) + np.cos(y))

# %%
x = np.linspace(-6, 6, 51)
y = np.linspace(-6, 6, 50)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
CS = plt.contourf(X, Y, Z)
plt.colorbar()

# %%
CS = plt.contour(X, Y, Z)
plt.clabel(CS, inline=1, fontsize=8)
# Out:
# <a list of 44 text.Text objects>

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
ax.view_init(60, 35)
fig

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.view_init(60, 35)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')

# %% [markdown]
# ## Try creating functions to compute filter-normalized training loss plots

# %%
from utils import ml_utils
ml_utils.init_env()

# %%
train, validation = ml_utils.load_batched_and_resized_dataset('cats_vs_dogs')
# Out:
# Training Data Summary
# No. of examples: 18610
# Class: 0 :::: Count: 9378 :::: Percentage: 50.39226222461043
# Class: 1 :::: Count: 9232 :::: Percentage: 49.60773777538957
#
# Validation Data Summary
# No. of examples: 4652
# Class: 0 :::: Count: 2280 :::: Percentage: 49.011177987962164
# Class: 1 :::: Count: 2372 :::: Percentage: 50.988822012037836

# %%
batch_32_model = ml_utils.build_model()
batch_32_model.load_weights('pickled_objects/batch_size_32_best_weights_trial_2.h5')
batch_32_weights = batch_32_model.get_weights()

batch_256_model = ml_utils.build_model()
batch_256_model.load_weights('pickled_objects/batch_size_256_best_weights_trial_2.h5')
batch_256_weights = batch_256_model.get_weights()

# %%
batch_32_x_values, batch_32_train_losses, batch_32_validation_losses = \
ml_utils.plot_loss_visualization_1d(batch_32_model, train, validation)
# Out:
# x:  -1.0
#     146/Unknown - 6s 44ms/step - loss: 1.0812 - accuracy: 0.5798
# x:  -0.8947368421052632
#     146/Unknown - 1s 10ms/step - loss: 0.8658 - accuracy: 0.6019
# x:  -0.7894736842105263
#     146/Unknown - 1s 9ms/step - loss: 0.7378 - accuracy: 0.6318- 1s 9ms/step  - 1s 9ms/step - loss: 0.7382 - accuracy
# x:  -0.6842105263157895
#     146/Unknown - 1s 10ms/step - loss: 0.6499 - accuracy: 0.6679
# x:  -0.5789473684210527
#     146/Unknown - 1s 10ms/step - loss: 0.5724 - accuracy: 0.7087
# x:  -0.4736842105263158
#     146/Unknown - 1s 10ms/step - loss: 0.4901 - accuracy: 0.7599
# x:  -0.368421052631579
#     146/Unknown - 1s 10ms/step - loss: 0.4197 - accuracy: 0.8044
# x:  -0.26315789473684215
#     146/Unknown - 1s 10ms/step - loss: 0.3759 - accuracy: 0.8330
# x:  -0.1578947368421053
#     146/Unknown - 1s 10ms/step - loss: 0.3544 - accuracy: 0.8390 1s 10ms/step - loss: 0.3554 - ac
# x:  -0.052631578947368474
# ...

# %%
batch_256_x_values, batch_256_train_losses, batch_256_validation_losses = \
ml_utils.plot_loss_visualization_1d(batch_256_model, train, validation)
# Out:
# x:  -1.0
#     146/Unknown - 1s 10ms/step - loss: 1.9035 - accuracy: 0.5127
# x:  -0.8947368421052632
#     146/Unknown - 1s 10ms/step - loss: 1.4431 - accuracy: 0.5191
# x:  -0.7894736842105263
#     146/Unknown - 1s 10ms/step - loss: 1.1682 - accuracy: 0.5224
# x:  -0.6842105263157895
#     146/Unknown - 2s 10ms/step - loss: 1.0119 - accuracy: 0.5236
# x:  -0.5789473684210527
#     146/Unknown - 1s 10ms/step - loss: 0.9242 - accuracy: 0.5271
# x:  -0.4736842105263158
#     146/Unknown - 1s 10ms/step - loss: 0.8616 - accuracy: 0.5316
# x:  -0.368421052631579
#     146/Unknown - 1s 10ms/step - loss: 0.7921 - accuracy: 0.5559
# x:  -0.26315789473684215
#     146/Unknown - 1s 10ms/step - loss: 0.6642 - accuracy: 0.6466
# x:  -0.1578947368421053
#     146/Unknown - 1s 10ms/step - loss: 0.4863 - accuracy: 0.7681
# x:  -0.052631578947368474
#     146/Unknown - 1s 10ms/step - loss: 0.3855 - accuracy: 0.8229
# x:  0.05263157894736836
# ...

# %%
from matplotlib import pyplot as plt
plt.plot(batch_256_x_values, batch_256_train_losses, label='256')
plt.plot(batch_256_x_values, batch_32_train_losses, label='32')
plt.legend()

# %%
batch_32_X, batch_32_Y, batch_32_Z = ml_utils.plot_loss_visualization_2d(batch_32_model, train, mode='all')
# Out:
#  x: -1.0, y: -1.0
#     582/Unknown - 24s 41ms/step - loss: 2.8892 - accuracy: 0.5397
#  x: -0.5, y: -1.0
#     582/Unknown - 6s 10ms/step - loss: 1.2564 - accuracy: 0.5796
#  x: 0.0, y: -1.0
#     582/Unknown - 6s 10ms/step - loss: 1.0020 - accuracy: 0.5890
#  x: 0.5, y: -1.0
#     582/Unknown - 6s 10ms/step - loss: 2.0021 - accuracy: 0.5243
#  x: 1.0, y: -1.0
#     582/Unknown - 6s 10ms/step - loss: 6.2500 - accuracy: 0.5007 5s 9ms/
#  x: -1.0, y: -0.5
#     582/Unknown - 6s 10ms/step - loss: 1.3930 - accuracy: 0.5908 5s 10ms/
#  x: -0.5, y: -0.5
#     582/Unknown - 6s 10ms/step - loss: 0.6466 - accuracy: 0.6941
#  x: 0.0, y: -0.5
#     582/Unknown - 6s 10ms/step - loss: 0.5092 - accuracy: 0.7521
#  x: 0.5, y: -0.5
#     582/Unknown - 6s 10ms/step - loss: 0.6269 - accuracy: 0.6837
#  x: 1.0, y: -0.5
#     582/Unknown - 6s 10ms/step - loss: 1.3710 - accuracy: 0.5466
#  x: -1.0, y: 0.0
#     582/Unknown - 6s 10ms/step - loss: 0.9343 - accuracy: 0.6621
#  x: -0.5, y: 0.0
# ...

# %%
ml_utils.plot_loss_visualization_2d(batch_32_model, train, mode='all', XYZ=(batch_32_X, batch_32_Y, batch_32_Z))
# Out:
# (array([[-1. , -0.5,  0. ,  0.5,  1. ],
#         [-1. , -0.5,  0. ,  0.5,  1. ],
#         [-1. , -0.5,  0. ,  0.5,  1. ],
#         [-1. , -0.5,  0. ,  0.5,  1. ],
#         [-1. , -0.5,  0. ,  0.5,  1. ]]),
#  array([[-1. , -1. , -1. , -1. , -1. ],
#         [-0.5, -0.5, -0.5, -0.5, -0.5],
#         [ 0. ,  0. ,  0. ,  0. ,  0. ],
#         [ 0.5,  0.5,  0.5,  0.5,  0.5],
#         [ 1. ,  1. ,  1. ,  1. ,  1. ]]),
#  array([[ 2.88919314,  1.25642704,  1.00200322,  2.00205122,  6.24999998],
#         [ 1.39303908,  0.64663441,  0.50919325,  0.62689957,  1.37100106],
#         [ 0.9343321 ,  0.37728348,  0.18260796,  0.34211473,  1.00214955],
#         [ 1.30222088,  0.55726357,  0.4661113 ,  1.1104299 ,  1.76041159],
#         [ 3.52042313,  2.35163495,  4.48597355,  6.07848327, 10.01899047]]))

# %%
batch_256_X, batch_256_Y, batch_256_Z = ml_utils.plot_loss_visualization_2d(batch_256_model, train, mode='all')
# Out:
#  x: -1.0, y: -1.0
#     582/Unknown - 6s 10ms/step - loss: 6.2015 - accuracy: 0.5046
#  x: -0.5, y: -1.0
#     582/Unknown - 6s 10ms/step - loss: 0.9666 - accuracy: 0.5612
#  x: 0.0, y: -1.0
#     582/Unknown - 6s 10ms/step - loss: 0.8687 - accuracy: 0.5910
#  x: 0.5, y: -1.0
#     582/Unknown - 6s 9ms/step - loss: 1.0990 - accuracy: 0.5563
#  x: 1.0, y: -1.0
#     582/Unknown - 6s 10ms/step - loss: 1.9756 - accuracy: 0.5359
#  x: -1.0, y: -0.5
#     582/Unknown - 6s 10ms/step - loss: 2.9170 - accuracy: 0.5142
#  x: -0.5, y: -0.5
#     582/Unknown - 6s 10ms/step - loss: 0.7614 - accuracy: 0.6038
#  x: 0.0, y: -0.5
#     582/Unknown - 6s 10ms/step - loss: 0.5911 - accuracy: 0.6915
#  x: 0.5, y: -0.5
#     582/Unknown - 6s 10ms/step - loss: 0.6550 - accuracy: 0.6560
#  x: 1.0, y: -0.5
#     582/Unknown - 6s 10ms/step - loss: 0.9677 - accuracy: 0.5601
#  x: -1.0, y: 0.0
#     582/Unknown - 6s 10ms/step - loss: 1.4886 - accuracy: 0.5749
#  x: -0.5, y: 0.0
# ...
